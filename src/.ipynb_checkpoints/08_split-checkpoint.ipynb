# %% [markdown]
# # Data Science Academy

# %% [markdown]
# https://www.datascienceacademy.com.br/start

# %% [markdown]
# ### Projeto com Feedback 3

# %% [markdown]
# Gabriel Quaiotti - Abr 2020

# %% [markdown]
# A satisfação do cliente é uma medida fundamental de sucesso. Clientes
# insatisfeitos cancelam seus serviços e raramente expressam sua insatisfação antes
# de sair. Clientes satisfeitos, por outro lado, se tornam defensores da marca!
# O Banco Santander está pedindo para ajudá-los a identificar clientes
# insatisfeitos no início do relacionamento. Isso permitiria que o Santander
# adotasse medidas proativas para melhorar a felicidade de um cliente antes que
# seja tarde demais.
# Neste projeto de aprendizado de máquina, você trabalhará com centenas
# de recursos anônimos para prever se um cliente está satisfeito ou insatisfeito com
# sua experiência bancária.
# Defina claramente o problema de negócio, faça a coleta e preparo dos
# dados, escolha um algoritmo, treine o modelo e avalie a acurácia, que deve ser de
# pelo menos 70%.

# %% [markdown]
# https://www.kaggle.com/c/santander-customer-satisfaction/overview/evaluation

# %%
# libraries
from pandas import read_csv
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve

from sklearn import tree

from sklearn.naive_bayes import GaussianNB

from sklearn import svm

from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # TRAIN / TEST SPLIT

# %%
selected_cols_corr_df = read_csv('../dataset/df_features_corr.csv')
selected_cols_corr_df.index = selected_cols_corr_df.ID

selected_cols_kbest_df = read_csv('../dataset/df_features_kbest.csv')
selected_cols_kbest_df.index = selected_cols_corr_df.ID

selected_cols_rfe_df = read_csv('../dataset/df_features_rfe.csv')
selected_cols_rfe_df.index = selected_cols_corr_df.ID

# %%
x = selected_cols_corr_df.drop(['ID', 'TARGET'], axis=1)
y = selected_cols_corr_df.TARGET

# Definindo o tamanho do conjunto de dados
test_size = 0.3

# Dividindo os dados em treino e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = test_size)

# %%
x_train.shape
# Out:
# (4211, 10)

# %%
x_test.shape
# Out:
# (1805, 10)

# %% [markdown]
# # TRAIN

# %% [markdown]
# ### Logistic Regression with MANUALLY selected features

# %%
# Criando o modelo
model = LogisticRegression()
model.fit(x_train, y_train)
predict = model.predict(x_test)

# %%
#extracting true_positives, false_positives, true_negatives, false_negatives
tn, fp, fn, tp = confusion_matrix(y_test, predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
print()

#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
print("Accuracy {:0.2f}%:", format(Accuracy))

plot_confusion_matrix(model, x_test, y_test, normalize= 'true')
plot_roc_curve(model, x_test, y_test)
# Out:
# True Negatives:  622
# False Positives:  287
# False Negatives:  253
# True Positives:  643
#
# Accuracy {:0.2f}%: 70.08310249307479

# %% [markdown]
# ### Decision Tree with  MANUALLY selected features

# %%
# Criando o modelo
model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predict = model.predict(x_test)

# %%
#extracting true_positives, false_positives, true_negatives, false_negatives
tn, fp, fn, tp = confusion_matrix(y_test, predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
print()

#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
print("Accuracy {:0.2f}%:", format(Accuracy))

plot_confusion_matrix(model, x_test, y_test, normalize= 'true')
plot_roc_curve(model, x_test, y_test)
# Out:
# True Negatives:  644
# False Positives:  265
# False Negatives:  284
# True Positives:  612
#
# Accuracy {:0.2f}%: 69.58448753462604

# %% [markdown]
# ### Naive Bayes with  MANUALLY selected features

# %%
model = GaussianNB()
model.fit(x_train, y_train)
predict = model.predict(x_test)

# %%
#extracting true_positives, false_positives, true_negatives, false_negatives
tn, fp, fn, tp = confusion_matrix(y_test, predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
print()

#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
print("Accuracy {:0.2f}%:", format(Accuracy))

plot_confusion_matrix(model, x_test, y_test, normalize= 'true')
plot_roc_curve(model, x_test, y_test)
# Out:
# True Negatives:  679
# False Positives:  230
# False Negatives:  347
# True Positives:  549
#
# Accuracy {:0.2f}%: 68.03324099722991

# %% [markdown]
# ### SVM with  MANUALLY selected features

# %%
model = svm.SVC()
model.fit(x_train, y_train)
predict = model.predict(x_test)

# %%
#extracting true_positives, false_positives, true_negatives, false_negatives
tn, fp, fn, tp = confusion_matrix(y_test, predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
print()

#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
print("Accuracy {:0.2f}%:", format(Accuracy))

plot_confusion_matrix(model, x_test, y_test, normalize= 'true')
plot_roc_curve(model, x_test, y_test)
# Out:
# True Negatives:  651
# False Positives:  258
# False Negatives:  287
# True Positives:  609
#
# Accuracy {:0.2f}%: 69.80609418282549

# %% [markdown]
# ### KNN with  MANUALLY selected features

# %%
model = KNeighborsClassifier()
model.fit(x_train, y_train)
predict = model.predict(x_test)

# %%
#extracting true_positives, false_positives, true_negatives, false_negatives
tn, fp, fn, tp = confusion_matrix(y_test, predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
print()

#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
print("Accuracy {:0.2f}%:", format(Accuracy))

plot_confusion_matrix(model, x_test, y_test, normalize= 'true')
plot_roc_curve(model, x_test, y_test)
# Out:
# True Negatives:  649
# False Positives:  260
# False Negatives:  276
# True Positives:  620
#
# Accuracy {:0.2f}%: 70.30470914127424
